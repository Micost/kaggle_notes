# %% [markdown]
# # Instroduction
#
# This note will create dataset for calulation

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

hf_token = user_secrets.get_secret("HUGGINGFACE_W")

login(token = hf_token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Generate ramdon numbers for operations

# %%
import random

def calculate(op, A, B):
  if op == '+':
    return A + B
  elif op == '-':
    return A - B
  elif op == '*':
    return A * B
  elif op == '/':
    if B == 0:
      return "Division by zero"
    else:
      return A / B
  else:
    return "Invalid operator"

def generate_dataset(num_samples):
  dataset = []
  operators = ['+', '-', '*', '/']
  for _ in range(num_samples):
    op = random.choice(operators)
    A = random.randint(1, 100)
    B = random.randint(1, 100)
    result = calculate(op, A, B)
    data = {
      "input": {
        "op": op,
        "A": A,
        "B": B
      },
      "output": {
        "result": result
      }
    }
    dataset.append(data)
  return dataset


data = generate_dataset(1000)


for item in data[:5]:
  print(item)
# Out:
# {'input': {'op': '*', 'A': 30, 'B': 47}, 'output': {'result': 1410}}
# {'input': {'op': '*', 'A': 50, 'B': 6}, 'output': {'result': 300}}
# {'input': {'op': '-', 'A': 36, 'B': 47}, 'output': {'result': -11}}
# {'input': {'op': '-', 'A': 86, 'B': 55}, 'output': {'result': 31}}
# {'input': {'op': '-', 'A': 83, 'B': 52}, 'output': {'result': 31}}

# %%
from datasets import Dataset

dataset = Dataset.from_list(data)

# %% [markdown]
# # Push to huggingface

# %%
from datasets import load_dataset


dataset.push_to_hub("micost/simple_calculation")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/481 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/micost/simple_calculation/commit/860e272b7a08ed1ed740489cfde583b4f6709cb7', commit_message='Upload dataset', commit_description='', oid='860e272b7a08ed1ed740489cfde583b4f6709cb7', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/micost/simple_calculation', endpoint='https://huggingface.co', repo_type='dataset', repo_id='micost/simple_calculation'), pr_revision=None, pr_num=None)
